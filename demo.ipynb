# %%
# !pip install colabxterm
# %load_ext colabxterm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Obtaining file:///mnt/e/Projects/colab-xterm
#   Preparing metadata (setup.py) ... done
# ...
#   Attempting uninstall: colab-xterm
#     Found existing installation: colab-xterm 0.1.0.dev1
#     Uninstalling colab-xterm-0.1.0.dev1:
#       Successfully uninstalled colab-xterm-0.1.0.dev1
#   Running setup.py develop for colab-xterm
# ...

# %%
# %xterm port=8080 fontsize=18 fontfamily="consolas"
# Out:
# Launching Xterm...
#       <iframe id="xterm-frame-c2371e4fbd0a8e4b" width="100%" height="800" frameborder="0"></iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("xterm-frame-c2371e4fbd0a8e4b");
#           const url = new URL("/", window.location);
#           const port = 8085;
#           if (port) {
#             url.port = port;
#           }
#           url.search = "?fontSize=18&fontFamily=consolas";
#           frame.src = url;
#         })();
#       </script>
